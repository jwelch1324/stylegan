# %%
import torch
import imageio
from einops import rearrange

# %%
img = imageio.imread('/data/ag_imgs/org/1j0buwtj0ul31.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (1160, 946, 3)

# %%
imt = torch.tensor(img)

# %%
imt.shape
# Out:
# torch.Size([1160, 946, 3])

# %%
rr = imt.unfold(0,200,100).unfold(1,200,100)

# %%
rr.shape
# Out:
# torch.Size([10, 8, 3, 200, 200])

# %%
rearrange(rr[0][0],'c w ')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-3661833525ff> in <module>
# ----> 1 plt.imshow(rr[0][0])
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2681         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2682         resample=resample, url=url, **({"data": data} if data is not
# -> 2683         None else {}), **kwargs)
#    2684     sci(__ret)
#    2685     return __ret
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
# ...

# %%
rearrange(img,'b ')
